# %%
import numpy as np
import scipy.linalg as la
import pandas as pd
import sklearn
import sympy
import ase
import pymatgen
import crystal_toolkit
import pymatviz
import hyperspy
import rsciio
import larch
import pywbem
import torch
import ovito
print('numpy', np.__version__)
print('scipy', la.det(np.eye(3)))
print('torch', torch.__version__, 'cuda', torch.cuda.is_available())
print('ALL_SCI_PACKAGES_OK', np.float64(3.1))
